# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/IAmSuyogJadhav/AML-Specialization-Exercises-Coursera/blob/master/train_car_horn_detection.ipynb)

# %% [markdown]
# # Car Horn Detection
